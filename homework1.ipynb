# %% [markdown]
# Homework 1: KNN and Data Splitting
# Будь ласка, не змінюйте назви функцій та структуру ноутбука. Пишіть код тільки там, де вказано # YOUR CODE HERE

# %%
import numpy as np
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score

def data_processing(test_size=0.2, val_size=0.2):
    # Завантажте iris, зробіть спочатку спліт на train/test,
    # а потім train на train/val.
    # YOUR CODE HERE
    pass

# %%
def find_best_k(X_train, y_train, X_val, y_val, k_range):
    # YOUR CODE HERE
    pass
